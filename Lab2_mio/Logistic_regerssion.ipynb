# %%
import numpy as np  
import matplotlib.pyplot as plt
import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

# %%
#Hyperparameters:

input_size = 784
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.05

# %%
#MNIST dataset (images and labels):

train_dataset = torchvision.datasets.MNIST(root='./data',
                                           train=True,
                                           transform=transforms.ToTensor(),
                                           download=True)

test_dataset = torchvision.datasets.MNIST(root='./data',
                                          train=False,
                                          transform=transforms.ToTensor())
#CONSIGLIO DI MOSTRARE SEMPRE LA DIMENSIONE DEI TENSORI CHE ABBIAMO CREATO.

# %%
#Data loader:

train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size,
                                           shuffle=True)

test_dataset = torch.utils.data.DataLoader(dataset=test_dataset,
                                           batch_size=batch_size,
                                           shuffle=False)
#voglio vedere le dimensioni del tensore:
print(train_dataset[0][0].shape)
# Out:
# torch.Size([1, 28, 28])

# %%
#Logistic regression model:

model = nn.Linear(in_features=input_size, out_features=num_classes)
'''
praticamente rispetto a Linear regression non cambia nulla nella definzione del modello. 
Questo perchè non ci serve implementare la funzione softmaz, dato che verrà usata
nella loss nn.CrossEntropyLoss()

la finzione CrossEntropyLoss() applica la funzione softmax direttamente all'input che gli diamo.
Pertanto il semplice input che gli diamo è il dot product.
'''
# Out:
# "\npraticamente rispetto a Linear regression non cambia nulla nella definzione del modello. \nQuesto perchè non ci serve implementare la funzione softmaz, dato che verrà usata\nnella loss nn.CrossEntropyLoss()\n\nla finzione CrossEntropyLoss() applica la funzione softmax direttamente all'input che gli diamo.\nPertanto il semplice input che gli diamo è il dot product.\n"

# %%
#Loss and optimizer:

#Loss Functions:
loss_fn = nn.CrossEntropyLoss()

#optimizer
optimizer= torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
#Train The Model:

total_step = len(train_loader)
for epoch in range(num_epochs):
    for idx , (images , lables) in enumerate(train_loader):
        #reshape images to (batch_size, input_size) ???
        ''' La shape se non la tocchiamo è un tensore [100,1,28,28] che è: batch, canali , h , l
        quindi 100 immagini per bach, un canale (grey scale) , 28 h , 28 l
            Il Layer linear non è pensato per gestire tensori 4D, quello che si aspetta è un tensore 2D
        In cui la prima dimensione è la batch, e la seconda sono le Features (pixel)
            Quindi dovrò ottenere un tensore [100, 784]
        '''
        images = images.reshape(batch_size,input_size) #--> [100,784] 
        ''' Potevamo mettere -1 al posto di batch size, e il compilatore lo calcola da solo
            L'organizzazione è comunque a matrice, dobbiamo immaginarla come 100 righe e
            784 colonne, che sono i pixels (features)
        '''
        #print(images.shape)
        #print(type(images))


        #forward pass:
        predictions = model(images)
        loss = loss_fn(predictions,lables)

        #Backward:
        optimizer.zero_grad() #azzero i gradienti
        loss.backward() #calcolo i gradienti
        optimizer.step() #aggiorno i pesi

        # Print the log info
        if (idx+1) % 100 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                   .format(epoch+1, num_epochs, idx+1, total_step, loss.item()))
# Out:
# Epoch [1/5], Step [100/600], Loss: 0.7647
# Epoch [1/5], Step [200/600], Loss: 0.6604
# Epoch [1/5], Step [300/600], Loss: 0.5232
# Epoch [1/5], Step [400/600], Loss: 0.5679
# Epoch [1/5], Step [500/600], Loss: 0.5501
# Epoch [1/5], Step [600/600], Loss: 0.3538
# Epoch [2/5], Step [100/600], Loss: 0.4165
# Epoch [2/5], Step [200/600], Loss: 0.4997
# Epoch [2/5], Step [300/600], Loss: 0.3870
# Epoch [2/5], Step [400/600], Loss: 0.2373
# Epoch [2/5], Step [500/600], Loss: 0.4367
# Epoch [2/5], Step [600/600], Loss: 0.3860
# Epoch [3/5], Step [100/600], Loss: 0.4059
# Epoch [3/5], Step [200/600], Loss: 0.3201
# Epoch [3/5], Step [300/600], Loss: 0.3274
# Epoch [3/5], Step [400/600], Loss: 0.4602
# Epoch [3/5], Step [500/600], Loss: 0.3258
# Epoch [3/5], Step [600/600], Loss: 0.4295
# Epoch [4/5], Step [100/600], Loss: 0.3619
# Epoch [4/5], Step [200/600], Loss: 0.2243
# Epoch [4/5], Step [300/600], Loss: 0.2819
# Epoch [4/5], Step [400/600], Loss: 0.4310
# Epoch [4/5], Step [500/600], Loss: 0.2608
# Epoch [4/5], Step [600/600], Loss: 0.3239
# Epoch [5/5], Step [100/600], Loss: 0.2281
# Epoch [5/5], Step [200/600], Loss: 0.3518
# Epoch [5/5], Step [300/600], Loss: 0.3303
# Epoch [5/5], Step [400/600], Loss: 0.3837
# Epoch [5/5], Step [500/600], Loss: 0.3844
# Epoch [5/5], Step [600/600], Loss: 0.2311

# %%
#Test Model:

with torch.no_grad():
    correct=0
    total=0
    for images, lables in test_dataset:
        images = images.reshape(-1, 28*28)
        outputs = model(images)
        
        _, predicted = torch.max(outputs.data, 1) #Lui mi da il vettore di predizioni, e io prendo solo il massimo.
        total += lables.size(0)
        correct += (predicted == lables).sum()

        print('Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))

    print(outputs.shape)
    print(outputs)
# Out:
# Accuracy of the model on the 10000 test images: 94.0 %
# Accuracy of the model on the 10000 test images: 95.0 %
# Accuracy of the model on the 10000 test images: 94.33333587646484 %
# Accuracy of the model on the 10000 test images: 93.0 %
# Accuracy of the model on the 10000 test images: 92.19999694824219 %
# Accuracy of the model on the 10000 test images: 91.0 %
# Accuracy of the model on the 10000 test images: 90.71428680419922 %
# Accuracy of the model on the 10000 test images: 90.75 %
# Accuracy of the model on the 10000 test images: 91.0 %
# Accuracy of the model on the 10000 test images: 90.5999984741211 %
# Accuracy of the model on the 10000 test images: 90.36363983154297 %
# Accuracy of the model on the 10000 test images: 90.25 %
# Accuracy of the model on the 10000 test images: 89.30769348144531 %
# Accuracy of the model on the 10000 test images: 89.28571319580078 %
# Accuracy of the model on the 10000 test images: 89.19999694824219 %
# Accuracy of the model on the 10000 test images: 89.125 %
# Accuracy of the model on the 10000 test images: 89.23529052734375 %
# Accuracy of the model on the 10000 test images: 89.0 %
# Accuracy of the model on the 10000 test images: 88.9473648071289 %
# Accuracy of the model on the 10000 test images: 88.6500015258789 %
# Accuracy of the model on the 10000 test images: 88.57142639160156 %
# Accuracy of the model on the 10000 test images: 88.40908813476562 %
# Accuracy of the model on the 10000 test images: 88.56521606445312 %
# Accuracy of the model on the 10000 test images: 88.45833587646484 %
# Accuracy of the model on the 10000 test images: 88.5999984741211 %
# Accuracy of the model on the 10000 test images: 88.65384674072266 %
# Accuracy of the model on the 10000 test images: 88.74073791503906 %
# Accuracy of the model on the 10000 test images: 88.85713958740234 %
# Accuracy of the model on the 10000 test images: 88.93103790283203 %
# Accuracy of the model on the 10000 test images: 88.93333435058594 %
# Accuracy of the model on the 10000 test images: 89.19355010986328 %
# Accuracy of the model on the 10000 test images: 89.09375 %
# Accuracy of the model on the 10000 test images: 89.18181610107422 %
# Accuracy of the model on the 10000 test images: 89.26470947265625 %
# Accuracy of the model on the 10000 test images: 89.42857360839844 %
# Accuracy of the model on the 10000 test images: 89.41666412353516 %
# Accuracy of the model on the 10000 test images: 89.48648834228516 %
# Accuracy of the model on the 10000 test images: 89.36842346191406 %
# Accuracy of the model on the 10000 test images: 89.1025619506836 %
# Accuracy of the model on the 10000 test images: 89.0250015258789 %
# Accuracy of the model on the 10000 test images: 89.04878234863281 %
# Accuracy of the model on the 10000 test images: 88.97618865966797 %
# Accuracy of the model on the 10000 test images: 88.93022918701172 %
# Accuracy of the model on the 10000 test images: 88.86363983154297 %
# Accuracy of the model on the 10000 test images: 88.82221984863281 %
# Accuracy of the model on the 10000 test images: 88.89130401611328 %
# Accuracy of the model on the 10000 test images: 89.0 %
# Accuracy of the model on the 10000 test images: 89.0625 %
# Accuracy of the model on the 10000 test images: 88.93877410888672 %
# Accuracy of the model on the 10000 test images: 88.94000244140625 %
# Accuracy of the model on the 10000 test images: 88.96078491210938 %
# Accuracy of the model on the 10000 test images: 89.05769348144531 %
# Accuracy of the model on the 10000 test images: 89.15093994140625 %
# Accuracy of the model on the 10000 test images: 89.31481170654297 %
# Accuracy of the model on the 10000 test images: 89.49090576171875 %
# Accuracy of the model on the 10000 test images: 89.66071319580078 %
# Accuracy of the model on the 10000 test images: 89.66666412353516 %
# Accuracy of the model on the 10000 test images: 89.75862121582031 %
# Accuracy of the model on the 10000 test images: 89.7966079711914 %
# Accuracy of the model on the 10000 test images: 89.81666564941406 %
# Accuracy of the model on the 10000 test images: 89.80327606201172 %
# Accuracy of the model on the 10000 test images: 89.83870697021484 %
# Accuracy of the model on the 10000 test images: 90.0 %
# Accuracy of the model on the 10000 test images: 90.078125 %
# Accuracy of the model on the 10000 test images: 90.0923080444336 %
# Accuracy of the model on the 10000 test images: 90.09091186523438 %
# Accuracy of the model on the 10000 test images: 90.08955383300781 %
# Accuracy of the model on the 10000 test images: 90.07353210449219 %
# Accuracy of the model on the 10000 test images: 90.18840789794922 %
# Accuracy of the model on the 10000 test images: 90.27143096923828 %
# Accuracy of the model on the 10000 test images: 90.38027954101562 %
# Accuracy of the model on the 10000 test images: 90.47222137451172 %
# Accuracy of the model on the 10000 test images: 90.52054595947266 %
# Accuracy of the model on the 10000 test images: 90.6351318359375 %
# Accuracy of the model on the 10000 test images: 90.63999938964844 %
# Accuracy of the model on the 10000 test images: 90.68421173095703 %
# Accuracy of the model on the 10000 test images: 90.75325012207031 %
# Accuracy of the model on the 10000 test images: 90.84615325927734 %
# Accuracy of the model on the 10000 test images: 90.73417663574219 %
# Accuracy of the model on the 10000 test images: 90.76249694824219 %
# Accuracy of the model on the 10000 test images: 90.77777862548828 %
# Accuracy of the model on the 10000 test images: 90.84146118164062 %
# Accuracy of the model on the 10000 test images: 90.89156341552734 %
# Accuracy of the model on the 10000 test images: 90.95237731933594 %
# Accuracy of the model on the 10000 test images: 91.01176452636719 %
# Accuracy of the model on the 10000 test images: 91.0813980102539 %
# Accuracy of the model on the 10000 test images: 91.17241668701172 %
# Accuracy of the model on the 10000 test images: 91.2727279663086 %
# Accuracy of the model on the 10000 test images: 91.37078857421875 %
# Accuracy of the model on the 10000 test images: 91.46666717529297 %
# Accuracy of the model on the 10000 test images: 91.4175796508789 %
# Accuracy of the model on the 10000 test images: 91.47826385498047 %
# Accuracy of the model on the 10000 test images: 91.5268783569336 %
# Accuracy of the model on the 10000 test images: 91.59574127197266 %
# Accuracy of the model on the 10000 test images: 91.62105560302734 %
# Accuracy of the model on the 10000 test images: 91.64583587646484 %
# Accuracy of the model on the 10000 test images: 91.63917541503906 %
# Accuracy of the model on the 10000 test images: 91.51020050048828 %
# Accuracy of the model on the 10000 test images: 91.43434143066406 %
# Accuracy of the model on the 10000 test images: 91.4000015258789 %
# torch.Size([100, 10])
# tensor([[-2.1075e+00,  1.1026e+00,  1.1155e+00,  8.5825e-01, -1.3313e+00,
#           1.8224e+00, -1.0307e+00, -3.7554e+00,  4.6405e+00, -1.7632e+00],
#         [-3.0731e+00, -6.3007e+00, -2.5432e+00, -9.9360e-01,  4.8575e+00,
#           1.5547e+00, -1.4740e+00, -1.6734e-01,  2.6277e+00,  4.6756e+00],
#         [ 6.4007e+00, -3.8279e+00, -7.5125e-01, -9.2448e-01, -1.0726e+00,
#           4.3441e+00, -1.0275e+00,  3.1738e-01, -2.4132e+00, -1.0683e+00],
#         [-5.0844e+00,  5.4547e+00,  1.8390e+00,  6.7966e-01,  4.3104e-01,
#          -1.8158e+00, -1.9693e+00, -2.3001e-01,  2.7273e+00, -1.2884e+00],
#         [ 1.1856e+00, -6.6345e-01,  2.1364e+00,  9.8550e-01,  5.7092e-01,
#           4.6255e-01, -8.2074e-01, -6.7497e-01, -9.9940e-01, -1.9601e+00],
#         [-1.9865e+00, -2.7808e+00,  1.7140e+00, -5.4106e-01, -1.1473e+00,
#          -5.2058e+00, -2.1110e+00,  4.1661e+00,  2.4094e+00,  4.8534e+00],
#         [-1.3948e+00, -3.1334e+00,  1.3263e+00, -3.5322e+00,  4.9343e+00,
#          -1.1977e+00,  2.7913e+00, -1.2069e+00,  1.7712e+00, -3.3552e-01],
#         [ 1.3640e+00, -1.2079e+00,  8.0719e-01, -3.1834e-01, -1.3394e+00,
#           4.7679e+00,  3.9905e-02, -2.0948e+00,  2.1575e+00, -3.7243e+00],
